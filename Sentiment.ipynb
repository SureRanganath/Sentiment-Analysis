# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core.pylabtools import figsize

plt.style.use('ggplot')

import nltk

# %%
# Read data
df = pd.read_csv('Reviews.csv')

df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
# size of the dataset
print(df.shape)
# let's decrease the size
df = df.head(500)
print(df.shape)
# Out:
# (568454, 10)
# (500, 10)

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
# dataset information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      500 non-null    int64
#  1   ProductId               500 non-null    str
#  2   UserId                  500 non-null    str
#  3   ProfileName             500 non-null    str
#  4   HelpfulnessNumerator    500 non-null    int64
#  5   HelpfulnessDenominator  500 non-null    int64
#  6   Score                   500 non-null    int64
#  7   Time                    500 non-null    int64
#  8   Summary                 500 non-null    str
#  9   Text                    500 non-null    str
# dtypes: int64(5), str(5)
# memory usage: 39.2 KB

# %%
ax = df['Score'].value_counts().sort_index() \
    .plot(kind='bar', title='review stars count', figsize=(10, 5))
ax.set_xlabel('Review Start')
plt.show()

# %%
example = df['Text'][50]
print(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.

# %%
#tokenizing the text
token = nltk.word_tokenize(example)
token[:10]
# Out:
# ['This', 'oatmeal', 'is', 'not', 'good', '.', 'Its', 'mushy', ',', 'soft']

# %%
tagged = nltk.pos_tag(token)
tagged[:10]
# Out:
# [('This', 'DT'),
#  ('oatmeal', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('Its', 'PRP$'),
#  ('mushy', 'NN'),
#  (',', ','),
#  ('soft', 'JJ')]

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   This/DT
#   oatmeal/NN
#   is/VBZ
#   not/RB
#   good/JJ
#   ./.
#   Its/PRP$
#   mushy/NN
#   ,/,
#   soft/JJ
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   like/VB
#   it/PRP
#   ./.
#   (ORGANIZATION Quaker/NNP Oats/NNPS)
#   is/VBZ
#   the/DT
#   way/NN
#   to/TO
#   go/VB
#   ./.)

# %% [markdown]
# # Sentiment Analysis using VADER sentiment Scoring
#  Vader = Valence Aware Dictionary and sentiment Reasoner

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm import tqdm

Intensity_Analyze = SentimentIntensityAnalyzer()

# %%
#checking the polarity score of a statement
Intensity_Analyze.polarity_scores('This is not good! ')
# Out:
# {'neg': 0.473, 'neu': 0.527, 'pos': 0.0, 'compound': -0.4015}

# %%
Intensity_Analyze.polarity_scores(example)
# Out:
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# Run Polarity Score on DataSet
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Text']
    myid = row['Id']
    res[myid] = Intensity_Analyze.polarity_scores(text)
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 1691.09it/s]

# %%
res
# Out:
# {1: {'neg': 0.0, 'neu': 0.695, 'pos': 0.305, 'compound': 0.9441},
#  2: {'neg': 0.138, 'neu': 0.862, 'pos': 0.0, 'compound': -0.5664},
#  3: {'neg': 0.091, 'neu': 0.754, 'pos': 0.155, 'compound': 0.8265},
#  4: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  5: {'neg': 0.0, 'neu': 0.552, 'pos': 0.448, 'compound': 0.9468},
#  6: {'neg': 0.029, 'neu': 0.809, 'pos': 0.163, 'compound': 0.883},
#  7: {'neg': 0.034, 'neu': 0.693, 'pos': 0.273, 'compound': 0.9346},
#  8: {'neg': 0.0, 'neu': 0.52, 'pos': 0.48, 'compound': 0.9487},
#  9: {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.6369},
#  10: {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'compound': 0.8313},
#  11: {'neg': 0.017, 'neu': 0.846, 'pos': 0.137, 'compound': 0.9746},
#  12: {'neg': 0.113, 'neu': 0.887, 'pos': 0.0, 'compound': -0.7579},
#  13: {'neg': 0.031, 'neu': 0.923, 'pos': 0.046, 'compound': 0.296},
#  14: {'neg': 0.0, 'neu': 0.355, 'pos': 0.645, 'compound': 0.9466},
# ...

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'Id'})
vaders = vaders.merge(df, how='left')

# %%
# now we merge both polarity score data and metadata
vaders.head()
# Out:
#    Id    neg    neu    pos  compound   ProductId          UserId  \
# 0   1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1   2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2   3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3   4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4   5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# ...

# %%
ax = sns.barplot(data=vaders, x='Score', y='compound')
ax.set_title('compound score by amazon Star Review')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
sns.barplot(data=vaders, x='Score', y='pos', ax=axs[0])
sns.barplot(data=vaders, x='Score', y='neu', ax=axs[1])
sns.barplot(data=vaders, x='Score', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %% [markdown]
# ***Using roBERTa PreTrained Model by HUGGING FACE***

# %%
# import the dependencies from Hugging Face

from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
# selecting Hugging Face model

MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# ...
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]

# %%
# VADER Results in Example
print(example)
Intensity_Analyze.polarity_scores(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# Run using Roberta Model

encoded_text = tokenizer(example, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
score_dict = {
    'robert_neg': scores[0],
    'robert_neu': scores[1],
    'robert_pos': scores[2],
}
print(score_dict)
# Out:
# {'robert_neg': np.float32(0.97635514), 'robert_neu': np.float32(0.020687466), 'robert_pos': np.float32(0.0029573706)}

# %%
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    score_dict = {
        'robert_neg': scores[0],
        'robert_neu': scores[1],
        'robert_pos': scores[2],
    }
    return score_dict

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    try:
        text = row['Text']
        myid = row['Id']
        vader_result = Intensity_Analyze.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f"vader_{key}"] = value
        roberta_result = polarity_scores_roberta(text)
        both = {**vader_result_rename, **roberta_result}
        res[myid] = both
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#  17%|█▋        | 84/500 [00:10<00:35, 11.76it/s]
# Broke for id 83
#  38%|███▊      | 189/500 [00:22<00:30, 10.07it/s]
# Broke for id 187
# 100%|██████████| 500/500 [01:01<00:00,  8.11it/s]

# %%
# because of large text we have error model is unable to tokenize and analyze the large text  ex: 83,187
error_text = df['Text'][187]
print(error_text)
# Out:
# My Scotties were full of hot spots and when I used this within a week all the hot spots were gone. The smell is kinda strong, but not bad. It's tolerablel.

# %%
result_df = pd.DataFrame(res).T
result_df = result_df.reset_index().rename(columns={'index': 'Id'})
result_df = result_df.merge(df, how='left')

# %%
result_df.head()
# Out:
#    Id  vader_neg  vader_neu  vader_pos  vader_compound  robert_neg  \
# 0   1      0.000      0.695      0.305          0.9441    0.009624
# 1   2      0.138      0.862      0.000         -0.5664    0.508986
# 2   3      0.091      0.754      0.155          0.8265    0.003229
# 3   4      0.000      1.000      0.000          0.0000    0.002295
# 4   5      0.000      0.552      0.448          0.9468    0.001635
#
#    robert_neu  robert_pos   ProductId          UserId  \
# 0    0.049980    0.940395  B001E4KFG0  A3SGXH7AUHU8GW
# 1    0.452414    0.038600  B00813GRG4  A1D87F6ZCVE5NK
# 2    0.098067    0.898704  B000LQOCH0   ABXLMWJIXXAIN
# 3    0.090219    0.907486  B000UA0QIQ  A395BORC6FGVXV
# 4    0.010302    0.988063  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# ...

# %% [markdown]
# ## compare both scores of vader and robert

# %%
result_df.columns
# Out:
# Index(['Id', 'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound',
#        'robert_neg', 'robert_neu', 'robert_pos', 'ProductId', 'UserId',
#        'ProfileName', 'HelpfulnessNumerator', 'HelpfulnessDenominator',
#        'Score', 'Time', 'Summary', 'Text'],
#       dtype='str')

# %%
sns.pairplot( data=result_df,vars = ['vader_neg', 'vader_neu', 'vader_pos', 'robert_neg', 'robert_neu', 'robert_pos'], hue='Score' , palette='tab10')
plt.show()

# %%
# default roBERTa Pipeline from Hugging face
from transformers import pipeline
model_path = "cardiffnlp/twitter-xlm-roberta-base-sentiment"
sentiment_task = pipeline("sentiment-analysis", model=model_path, tokenizer=model_path)
sentiment_task("Here is the example msg")
# Out:
# config.json:   0%|          | 0.00/841 [00:00<?, ?B/s]
# pytorch_model.bin: reconstructing file:   0%|          |  0.00B / 1.11GB
# pytorch_model.bin: downloading bytes:           |  0.00B
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 4
#       1 # default roBERTa Pipeline from Hugging face
#       2 from transformers import pipeline
#       3 model_path = "cardiffnlp/twitter-xlm-roberta-base-sentiment"
# ----> 4 sentiment_task = pipeline("sentiment-analysis", model=model_path, tokenizer=model_path)
#       5 sentiment_task("Here is the example msg")
#
# ...
